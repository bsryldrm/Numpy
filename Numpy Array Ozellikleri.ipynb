# %%
import numpy as np

# %%
np.random.randint(8, size=10)
# Out:
# array([1, 3, 5, 0, 7, 4, 2, 7, 7, 1])

# %%
a = np.random.randint(8, size=10)

# %% [markdown]
# * ndim = boyut sayısı
# * shapev= boyut bilgisi
# * size= eleman sayısı
# * dtype= veri tipi

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (10,)

# %%
a.size
# Out:
# 10

# %%
a.dtype
# Out:
# dtype('int32')

# %%
b = np.random.randint(8, size=(8,4))

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (8, 4)

# %%
b.size
# Out:
# 32

# %%
b.dtype
# Out:
# dtype('int32')

# %%
c = np.random.randint(8, size=(2,4,3,))

# %%
c.ndim
# Out:
# 3

# %%
c.shape
# Out:
# (2, 4, 3)

# %%
c.size
# Out:
# 24

# %%
c.dtype
# Out:
# dtype('int32')
